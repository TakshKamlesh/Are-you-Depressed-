# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def eye_features(open_eye_frames, closed_eye_frames, fps):
    
    # features = ['max','min','mean','variance','standard deviation','duration','duration_rate']
    
    return features

# %%
img = cv2.imread('image.webp')
plt.imshow(img)

# %%
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_eye.xml')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# %%
plt.imshow(roi_color)

# %%
eyes = eye_cascade.detectMultiScale(gray,1.3,5)

# %%
eye = []
for (x,y,xw,yh) in eyes:
    
    ceye = roi_color[y:y+yh,x:x+xw]
    eye.append(ceye)

# %%
plt.imshow(eye[1])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-34-ab7c66d0db17> in <module>
#       1 plt.imshow(eye[1])
# ----> 2 cv2.imshow('eye',eyes[1])
#       3 cv2.destoryAllWindows()
#
# error: OpenCV(4.1.0) /io/opencv/modules/highgui/src/precomp.hpp:131: error: (-215:Assertion failed) src_depth != CV_16F && src_depth != CV_32S in function 'convertToShow'

# %%
eyes
# Out:
# array([[268, 471, 241, 241],
#        [822, 423, 275, 275]], dtype=int32)
